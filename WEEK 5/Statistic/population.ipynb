# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt 
import matplotlib.ticker as ticker
import seaborn as sns

# %%
data = pd.read_csv('population2.csv')
data.head()
# Out:
#                   Country Name Country Code     Indicator Name Indicator Code  \
# 0                        Aruba          ABW  Population, total    SP.POP.TOTL
# 1  Africa Eastern and Southern          AFE  Population, total    SP.POP.TOTL
# 2                  Afghanistan          AFG  Population, total    SP.POP.TOTL
# 3   Africa Western and Central          AFW  Population, total    SP.POP.TOTL
# 4                       Angola          AGO  Population, total    SP.POP.TOTL
#
#           1960         1961         1962         1963         1964  \
# 0      54608.0      55811.0      56682.0      57475.0      58178.0
# 1  130692579.0  134169237.0  137835590.0  141630546.0  145605995.0
# 2    8622466.0    8790140.0    8969047.0    9157465.0    9355514.0
# 3   97256290.0   99314028.0  101445032.0  103667517.0  105959979.0
# 4    5357195.0    5441333.0    5521400.0    5599827.0    5673199.0
#
#           1965  ...         2013         2014         2015         2016  \
# ...

# %%
data['Country Code'].unique()
# Out:
# array(['ABW', 'AFE', 'AFG', 'AFW', 'AGO', 'ALB', 'AND', 'ARB', 'ARE',
#        'ARG', 'ARM', 'ASM', 'ATG', 'AUS', 'AUT', 'AZE', 'BDI', 'BEL',
#        'BEN', 'BFA', 'BGD', 'BGR', 'BHR', 'BHS', 'BIH', 'BLR', 'BLZ',
#        'BMU', 'BOL', 'BRA', 'BRB', 'BRN', 'BTN', 'BWA', 'CAF', 'CAN',
#        'CEB', 'CHE', 'CHI', 'CHL', 'CHN', 'CIV', 'CMR', 'COD', 'COG',
#        'COL', 'COM', 'CPV', 'CRI', 'CSS', 'CUB', 'CUW', 'CYM', 'CYP',
#        'CZE', 'DEU', 'DJI', 'DMA', 'DNK', 'DOM', 'DZA', 'EAP', 'EAR',
#        'EAS', 'ECA', 'ECS', 'ECU', 'EGY', 'EMU', 'ERI', 'ESP', 'EST',
#        'ETH', 'EUU', 'FCS', 'FIN', 'FJI', 'FRA', 'FRO', 'FSM', 'GAB',
#        'GBR', 'GEO', 'GHA', 'GIB', 'GIN', 'GMB', 'GNB', 'GNQ', 'GRC',
#        'GRD', 'GRL', 'GTM', 'GUM', 'GUY', 'HIC', 'HKG', 'HND', 'HPC',
#        'HRV', 'HTI', 'HUN', 'IBD', 'IBT', 'IDA', 'IDB', 'IDN', 'IDX',
#        'IMN', 'IND', 'INX', 'IRL', 'IRN', 'IRQ', 'ISL', 'ISR', 'ITA',
# ...

# %%
data[data['Country Name'].str.startswith('U',na=False)]
# Out:
#              Country Name Country Code     Indicator Name Indicator Code  \
# 8    United Arab Emirates          ARE  Population, total    SP.POP.TOTL
# 81         United Kingdom          GBR  Population, total    SP.POP.TOTL
# 247                Uganda          UGA  Population, total    SP.POP.TOTL
# 248               Ukraine          UKR  Population, total    SP.POP.TOTL
# 249   Upper middle income          UMC  Population, total    SP.POP.TOTL
# 250               Uruguay          URY  Population, total    SP.POP.TOTL
# 251         United States          USA  Population, total    SP.POP.TOTL
# 252            Uzbekistan          UZB  Population, total    SP.POP.TOTL
#
#              1960          1961          1962          1963          1964  \
# 8    1.334260e+05  1.409840e+05  1.488770e+05  1.570060e+05  1.653050e+05
# 81   5.240000e+07  5.280000e+07  5.325000e+07  5.365000e+07  5.400000e+07
# 247  7.617746e+06  7.838440e+06  8.068828e+06  8.311013e+06  8.564755e+06
# ...

# %%
Oman = data[data['Country Name'] == 'Oman'].reset_index(drop=True)
UK = data[data['Country Code'] == 'GBR'].reset_index(drop=True)
USA = data[data['Country Code'] == 'USA'].reset_index(drop=True)

# %%
UK
# Out:
#      Country Name Country Code     Indicator Name Indicator Code        1960  \
# 0  United Kingdom          GBR  Population, total    SP.POP.TOTL  52400000.0
#
#          1961        1962        1963        1964        1965  ...  \
# 0  52800000.0  53250000.0  53650000.0  54000000.0  54348050.0  ...
#
#          2013        2014        2015        2016        2017        2018  \
# 0  64128273.0  64602298.0  65116219.0  65611593.0  66058859.0  66460344.0
#
#          2019        2020        2021  2022
# 0  66836327.0  67081000.0  67326569.0   NaN
#
# [1 rows x 67 columns]

# %%
Oman.drop(columns=(['Country Code','Indicator Name','Indicator Code']),inplace=True)
UK.drop(columns=(['Country Code','Indicator Name','Indicator Code']),inplace=True)
USA.drop(columns=(['Country Code','Indicator Name','Indicator Code']),inplace=True)

# %%
Oman = Oman.melt(id_vars='Country Name',var_name='Year',value_name='Population')
UK = UK.melt(id_vars='Country Name',var_name='Year',value_name='Population')
USA = USA.melt(id_vars='Country Name',var_name='Year',value_name='Population')

# %%
Oman
# Out:
#    Country Name  Year  Population
# 0          Oman  1960    536553.0
# 1          Oman  1961    546443.0
# 2          Oman  1962    557139.0
# 3          Oman  1963    568603.0
# 4          Oman  1964    580824.0
# ..          ...   ...         ...
# 58         Oman  2018   4601157.0
# 59         Oman  2019   4602768.0
# 60         Oman  2020   4543399.0
# 61         Oman  2021   4520471.0
# 62         Oman  2022         NaN
#
# [63 rows x 3 columns]

# %%
Oman['Population'].mean()
# Out:
# 1970949.5

# %%
plt.figure(figsize=(12,8))
plt.hist(Oman['Population'],bins=30,edgecolor='black')
plt.title('Population Distribution from 1960 to 2021')
plt.xlabel('Population')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(12,8))
plt.hist(UK['Population'],bins=30,edgecolor='black')
plt.title('Population Distribution from 1960 to 2021')
plt.xlabel('Population')
plt.ylabel('Frequency');

# %%
plt.figure(figsize=(12,8))
plt.hist(USA['Population'],bins=30,edgecolor='black')
plt.title('Population Distrbution from 1960 to 2021')
plt.xlabel('Population')
plt.ylabel('Frequency');

# %%
fig,ax = plt.subplots()
ax.bar(Oman['Year'],Oman['Population'])
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=45)
plt.title('Oman Population from 1960 to 2021')
plt.xlabel('Year')
plt.ylabel('Population');

# %%
fig,ax = plt.subplots()
plt.bar(UK['Year'],UK['Population'])
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=45)
plt.title('UK Population from 1960 to 2021')
plt.xlabel('Year')
plt.ylabel('Population');

# %%
fig,ax = plt.subplots()
plt.bar(USA['Year'],USA['Population'])
ax.xaxis.set_major_locator(ticker.MultipleLocator(5))
plt.xticks(rotation=45)
plt.title('USA population from 1960 to 2021')
plt.xlabel('Year')
plt.ylabel('Population');

# %%
OmanData = pd.read_excel('OmanPop.xlsx')
OmanData.head()
# Out:
#   Residential Status Alive  Age  Count
# 0              Omani   Yes    0  66770
# 1              Omani   Yes    1  76239
# 2              Omani   Yes    2  76280
# 3              Omani   Yes    3  79481
# 4              Omani   Yes    4  81384

# %%
OmanData.rename(columns=({'Residential Status':'Residential'}),inplace=True)
OmanData.drop(columns='Alive',inplace=True)
OmanData
# Out:
#     Residential  Age  Count
# 0         Omani    0  66770
# 1         Omani    1  76239
# 2         Omani    2  76280
# 3         Omani    3  79481
# 4         Omani    4  81384
# ..          ...  ...    ...
# 227   Non-Omani  109      3
# 228   Non-Omani  110      1
# 229   Non-Omani  112      2
# 230   Non-Omani  114      1
# 231   Non-Omani  119      1
#
# [232 rows x 3 columns]

# %%
Omani = OmanData[OmanData['Residential'] == 'Omani'].reset_index(drop=True)
NonOmani = OmanData[OmanData['Residential'] == 'Non-Omani'].reset_index(drop=True)

# %%
Omani
# Out:
#     Residential  Age  Count
# 0         Omani    0  66770
# 1         Omani    1  76239
# 2         Omani    2  76280
# 3         Omani    3  79481
# 4         Omani    4  81384
# ..          ...  ...    ...
# 114       Omani  114      2
# 115       Omani  115      2
# 116       Omani  116      1
# 117       Omani  117      1
# 118       Omani  118      6
#
# [119 rows x 3 columns]

# %%
fig,ax = plt.subplots(figsize = (12,8))
plt.bar(Omani['Age'],Omani['Count'])
plt.xticks(rotation=45)
plt.title('Omani population per Age group')
plt.xlabel('Age')
plt.ylabel('Population')
# Out:
# Text(0, 0.5, 'Population')

# %%
plt.figure(figsize=(12,8))
sns.histplot(data=Omani,x='Count',kde=True)
# Out:
# <AxesSubplot:xlabel='Count', ylabel='Count'>

# %%
import seaborn as sns

plt.figure(figsize=(10,6))
sns.histplot(data=df, x='population', bins=30, kde=True)
plt.title('Population Distribution by Age Group')
plt.xlabel('Population')
plt.ylabel('Frequency')
plt.show()

# %%
sns.distplot(Omani['Age'],
            rug=True,
            axlabel='Number of Character')

plt.ylabel('character per name');
# Out:
# /Users/mu/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# /Users/mu/opt/anaconda3/lib/python3.9/site-packages/seaborn/distributions.py:2103: FutureWarning: The `axis` variable is no longer used and will be removed. Instead, assign variables directly to `x` or `y`.
#   warnings.warn(msg, FutureWarning)
