# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
positive = np.random.rand(100,1)
y_positive = 3 * positive + np.random.randn(100,1)
positive[4:9]
# Out:
# array([[0.52881261],
#        [0.5745438 ],
#        [0.61595924],
#        [0.44396976],
#        [0.29933053]])

# %%
from sklearn.linear_model import LinearRegression

positive_model = LinearRegression()
positive_model.fit(positive,y_positive)
positive_model.coef_,positive_model.intercept_
# Out:
# (array([[3.02496654]]), array([0.06242717]))

# %%
positive_pred = positive_model.predict(positive)

# %%
plt.figure(figsize=(10,6))
plt.plot(positive,y_positive,'b.',label = ' Actual Data')
plt.plot(positive,positive_pred,color='red');

# %%
negative = np.random.rand(100,1)
y_negative = -3 * negative + np.random.randn(100,1)

negative_model = LinearRegression()
negative_model.fit(negative,y_negative)

negative_model.coef_,negative_model.intercept_
# Out:
# (array([[-3.13155804]]), array([-0.07948038]))

# %%
plt.figure(figsize=(10,6))
plt.plot(negative,y_negative,'b.')
plt.plot(negative,negative_model.predict(negative),color='red');

# %%
nonLinear = np.random.rand(100,1)
y_nonLinear = nonLinear ** 2 
plt.plot(nonLinear,y_nonLinear,'b.')

# %%
nonLinearModel = LinearRegression()
nonLinearModel.fit(nonLinear,y_nonLinear)

nonLinearModel.coef_,nonLinearModel.intercept_
# Out:
# (array([[0.9884309]]), array([-0.15627133]))

# %%
plt.figure(figsize=(10,6))
plt.plot(nonLinear,y_nonLinear,'b.')
plt.plot(nonLinear,nonLinearModel.predict(nonLinear),color='red');

# %%
noRelation = np.random.rand(100,1)
y_noRelation = np.random.rand(100,1)
plt.plot(noRelation,y_noRelation,'b.');

# %%
noRelationModel = LinearRegression()
noRelationModel.fit(noRelation,y_noRelation)
noRelationModel.coef_,noRelationModel.intercept_
# Out:
# (array([[-0.10840262]]), array([0.54564099]))

# %%
plt.figure(figsize=(10,6))
plt.plot(noRelation,y_noRelation,'b.')
plt.plot(noRelation,noRelationModel.predict(noRelation),color='red');

# %%
SGDR = np.random.rand(100,1)
y_SGDR = np.random.randn(100,1)

# %%
from sklearn.linear_model import SGDRegressor 

SGDRmodel = SGDRegressor()
SGDRegressor.fit(SGDR,y_SGDR)

y_pred_SGDE = SGDRmodel.predict(SGDR)
y_pred_SGDE
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [260], in <cell line: 4>()
#       1 from sklearn.linear_model import SGDRegressor
#       3 SGDRmodel = SGDRegressor()
# ----> 4 SGDRegressor.fit(SGDR,y_SGDR)
#       6 y_pred_SGDE = SGDRmodel.predict(SGDR)
#       7 y_pred_SGDE
#
# TypeError: fit() missing 1 required positional argument: 'y'

# %%
X = np.random.randint(0, 100, size=100).reshape((-1, 1))
y = X ** 2 
# y = y + 8

# %%
X[:3], y[:3]
# Out:
# (array([[28],
#         [92],
#         [87]]),
#  array([[ 784],
#         [8464],
#         [7569]]))

# %%
model_2 = LinearRegression()
model_2.fit(X, y)
# Out:
# LinearRegression()

# %%
model_2.coef_, model_2.intercept_
# Out:
# (array([[98.47431296]]), array([-1486.7206422]))

# %%
x_plt = np.random.randint(0, 100, size=100).reshape((-1, 1))
y_plt = model_2.predict(x_plt)

# %%
plt.figure(figsize=(10,6))
plt.plot(X, y,'b.',label = 'Actual data')
plt.plot(x_plt, y_plt, color='red',label = 'Fitted line')
plt.legend()
plt.show()

# %%
X_train = np.array([6,8,10,14,18]).reshape(-1,1)
# y_train = np.array([1,2.5,3,4.8,5]).reshape(-1,1)
y_train = X_train ^ 5
y_train = y_train + 2
# X_test = np.array([7,9,11,12,16]).reshape(-1,1)
# y_test = np.array([2,3.2,3.7,4.3,5.3]).reshape(-1,1)

# %%
plt.plot(X_train,y_train,'b.')

# %%
plt.plot(X_test,y_test,'b.')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [64], in <cell line: 1>()
# ----> 1 plt.plot(X_test,y_test,'b.')
#
# NameError: name 'X_test' is not defined

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)

y_pred = model.predict(X_train)
y_pred
# Out:
# array([[ 8.72413793],
#        [11.13793103],
#        [13.55172414],
#        [18.37931034],
#        [23.20689655]])

# %%
y_test = y_train

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,mean_absolute_percentage_error,mean_absolute_error
print(f'Coefficients: {model.coef_,model.intercept_}')
print('Mean Squared Error: %.2f' % mean_squared_error(y_test, y_pred))
print(f'Mean absolute error: %.2f' %mean_absolute_error(y_test,y_pred))
print(f'Mean absolute percentage error: %.2f' %mean_absolute_percentage_error(y_test,y_pred))
print('Coefficient of Determination: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients: (array([[1.20689655]]), array([1.48275862]))
# Mean Squared Error: 14.57
# Mean absolute error: 3.64
# Mean absolute percentage error: 0.34
# Coefficient of Determination: 0.65

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_train,y_train,label = 'train data')
#plt.plot(X_test,y_test,'r.',label = 'test data')
plt.plot(X_train,model.predict(X_train),color='pink', label= 'Fitted line X Train')
#plt.plot(X_test,model.predict(X_test),color='red', label= 'Fitted line X Test')
plt.plot(X_train,model.predict(X_train),'bo',label= 'Prediction for X Train')
#plt.plot(X_test,y_pred,'go',label= 'Prediction for X Test')
plt.legend()
#plt.xlabel('X')
#plt.ylabel('Y')
#plt.title('Linear Regression Fit')
#plt.xlim(0,19)
#plt.ylim(0,26)
plt.grid()
print(model.coef_,model.intercept_);
# Out:
# [[1.20689655]] [1.48275862]

# %%
model.coef_, model.intercept_
# Out:
# (array([[1.20689655]]), array([1.48275862]))

# %%
y = mX + b

# %%
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score
print(f'Coefficients: {model.coef_}')
print('Mean Squared Error: %.2f' % mean_squared_error(y_test, y_pred))
print('Coefficient of Determination: %.2f' % r2_score(y_test, y_pred))
# Out:
# Coefficients: [[0.33017241]]
# Mean Squared Error: 0.31
# Coefficient of Determination: 0.75

# %%
plt.figure(figsize=(10,6))
plt.plot(X_train,y_train,'b.',label = 'train data')
plt.plot(X_test,y_test,'r.',label = 'test data')
plt.plot(X_train,model.predict(X_train),color='pink', label= 'Fitted line X Train')
plt.plot(X_test,model.predict(X_test),color='red', label= 'Fitted line X Test')
plt.plot(X_train,model.predict(X_train),'bo',label= 'Prediction for X Train')
plt.plot(X_test,y_pred,'go',label= 'Prediction for X Test')
plt.legend()
plt.xlabel('X')
plt.ylabel('Y')
plt.title('Linear Regression Fit')
plt.grid();

# %%
# Generate a range of X values for prediction
X_range = np.linspace(min(X), max(X), 100).reshape(-1,1)

# Predict y values for the range of X values
y_range_pred = model.predict(X_range)

# Plot original data points
plt.plot(X, y, 'b.', label='Original data')

# Plot the fitted line
plt.plot(X_range, y_range_pred, 'r-', label='Fitted line')

# Highlight the prediction for X=13
plt.plot(13, y_pred, 'go', label='Prediction for X=13')

plt.xlabel('X')
plt.ylabel('y')
plt.title('Linear Regression Fit')
plt.legend()

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [23], in <cell line: 14>()
#      11 plt.plot(X_range, y_range_pred, 'r-', label='Fitted line')
#      13 # Highlight the prediction for X=13
# ---> 14 plt.plot(13, y_pred, 'go', label='Prediction for X=13')
#      16 plt.xlabel('X')
#      17 plt.ylabel('y')
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py:2757, in plot(scalex, scaley, data, *args, **kwargs)
#    2755 @_copy_docstring_and_deprecators(Axes.plot)
#    2756 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2757     return gca().plot(
#    2758         *args, scalex=scalex, scaley=scaley,
#    2759         **({"data": data} if data is not None else {}), **kwargs)
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/matplotlib/axes/_axes.py:1632, in Axes.plot(self, scalex, scaley, data, *args, **kwargs)
# ...

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
X_train = np.array([6,8,10,14,18]).reshape(-1,1)
y_train = X_train ** 5
y_train = y_train + 2

# %%
plt.figure(figsize=(10,6))
plt.scatter(X_train,y_train);

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train,y_train)

y_pred = model.predict(X_train)
y_pred
# Out:
# array([[-275918.55172414],
#        [  27738.27586207],
#        [ 331395.10344828],
#        [ 938708.75862069],
#        [1546022.4137931 ]])

# %%
print(model.coef_,model.intercept_)
# Out:
# [[151828.4137931]] [-1186889.03448276]

# %%
plt.figure(figsize=(8,6))
plt.scatter(X_train,y_train)
plt.plot(X_train,y_pred,color='pink',alpha = .6)
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.title('Linear Regression Model Fit');
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score, mean_absolute_percentage_error
import matplotlib.pyplot as plt

# Data preparation
X_train = np.array([6,8,10,14,18]).reshape(-1,1)
y_train = X_train ** 5
y_train = y_train + 2

# Model training
model = LinearRegression()
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_train)

# Testing
y_test = y_train

# Metrics
coefficients = model.coef_, model.intercept_
mse = mean_squared_error(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
mape = mean_absolute_percentage_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# Plotting
plt.figure(figsize=(8,6))
plt.scatter(X_train, y_train, color='blue', label='Training data')
plt.plot(X_train, model.predict(X_train), color='red', label='Fitted line')
plt.scatter(X_train, y_pred, color='green', label='Predictions')
plt.xlabel('X')
plt.ylabel('y')
plt.legend()
plt.grid(True)
plt.title('Linear Regression Model Fit')

# Return metrics and plot
coefficients, mse, mae, mape, r2, plt
# Out:
# ((array([[151828.4137931]]), array([-1186889.03448276])),
#  82556750035.86214,
#  252910.34482758626,
#  7.9737698235590155,
#  0.8382506933218822,
#  <module 'matplotlib.pyplot' from '/Users/mu/opt/anaconda3/lib/python3.9/site-packages/matplotlib/pyplot.py'>)

# %%
import pandas as pd

# %%
data = {'Hours of Sunshine' : [2,3,5,7,9],
       'Ice Creams sold' : [4,5,7,10,15]}
data = pd.DataFrame(data)
data
# Out:
#    Hours of Sunshine  Ice Creams sold
# 0                  2                4
# 1                  3                5
# 2                  5                7
# 3                  7               10
# 4                  9               15

# %%
X = data['Hours of Sunshine'].values.reshape(-1,1)
y = data['Ice Creams sold'].values

iceModel = LinearRegression()
iceModel.fit(X,y)
y_icepred = iceModel.predict(X)

y_icepred,iceModel.coef_[0],iceModel.intercept_, mean_squared_error(y,y_icepred)
# Out:
# (array([ 3.34146341,  4.8597561 ,  7.89634146, 10.93292683, 13.9695122 ]),
#  1.5182926829268288,
#  0.3048780487804894,
#  0.6378048780487806)

# %%
plt.figure(figsize=(10,6))
plt.plot(X,y,'b.',label = 'Actual data')
plt.plot(X,iceModel.predict(X),color='red', label = 'fitted line',alpha=.6)
plt.plot(X,iceModel.predict(X),'go', label = 'pred data',alpha=.6)

plt.legend()
plt.grid();

# %%
from sklearn.linear_model import SGDRegressor

SGDRmodel = SGDRegressor(max_iter =50, eta0=0.001)
SGDRmodel.fit(X,y.squeeze())
y_predSGDR = SGDRmodel.predict(X)
y_predSGDR, SGDRmodel.coef_[0], SGDRmodel.intercept_[0],mean_squared_error(y,y_predSGDR)
# Out:
# /Users/mu/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_stochastic_gradient.py:1503: ConvergenceWarning: Maximum number of iteration reached before convergence. Consider increasing max_iter to improve the fit.
#   warnings.warn(
# (array([ 3.11255632,  4.55444418,  7.4382199 , 10.32199563, 13.20577135]),
#  1.4418878612278037,
#  0.2287805986230803,
#  0.900210117693615)

# %%
plt.figure(figsize=(10,6))
plt.plot(X,y,'b.', label = 'actual data')
plt.plot(X,y_predSGDR,color='red', label = 'fitted line')
plt.plot(X,y_predSGDR,'go', label = 'pred data')
plt.legend()
plt.grid();

# %%
mse = mean_squared_error(y, y_pred)

# Linear Regression Parameters
slope = model.coef_[0]
intercept = model.intercept_

# Gradient Descent
# Initialize parameters
alpha = 0.01  # Learning rate
iters = 1000  # Number of iterations
theta = np.array([0.0, 0.0])  # Initial values of theta

# Implement Gradient Descent Function
def gradient_descent(X, y, theta, alpha, iters):
    m = len(y)
    J_history = np.zeros(iters)
    theta_history = np.zeros((iters,2))
    for i in range(iters):
        h = np.dot(X, theta)
        loss = h - y
        gradient = (2/m) * np.dot(X.T, loss)
        theta = theta - alpha * gradient
        J_history[i] = np.sum(loss**2) / (2 * m)
        theta_history[i,:] = theta.T
    return theta, J_history, theta_history

# Add a column of ones to X for the intercept term
X_gd = np.c_[np.ones((len(X), 1)), X]

# Run the gradient descent function
theta, J_history, theta_history = gradient_descent(X_gd, y, theta, alpha, iters)

# Create a grid for theta values
T0, T1 = np.meshgrid(range(-10, 10), range(-10, 10))

# Compute the cost function for each combination of T0 and T1
zs = np.array([np.sum((np.dot(X_gd, np.array([t0, t1])) - y)**2)/(2*len(y)) 
               for t0, t1 in zip(np.ravel(T0), np.ravel(T1))])
Z = zs.reshape(T0.shape)

# Plot Gradient Descent
fig = plt.figure(figsize=(14, 6))

# Subplot for cost function
ax1 = fig.add_subplot(1, 2, 1, projection='3d')
ax1.plot_surface(T0, T1, Z, rstride=1, cstride=1, alpha=0.6, cmap=plt.cm.jet)
ax1.set_xlabel('Intercept')
ax1.set_ylabel('Slope')
ax1.set_zlabel('Cost')
ax1.set_title('Cost function')

# Subplot for gradient descent
ax2 = fig.add_subplot(1, 2, 2)
ax2.contour(T0, T1, Z, np.logspace(-2, 3, 20), cmap=plt.cm.jet)
ax2.plot(theta_history[:,0], theta_history[:,1], 'r-')
ax2.plot(theta_history[:,0], theta_history[:,1], 'bo')
ax2.set_xlabel('Intercept')
ax2.set_ylabel('Slope')
ax2.set_title('Gradient descent')

plt.tight_layout()
plt.show()

# Return the final parameters, mean squared error, and the initial slope and intercept
theta, mse, slope, intercept
# Out:
# (array([0.30341047, 1.5185211 ]),
#  0.6378048780487806,
#  1.5182926829268288,
#  0.3048780487804894)

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
X_train_poly = poly.fit_transform(X)
#X_test_poly = poly.transform(X_test)

model_poly = LinearRegression()
model_poly.fit(X,y)

y_pred_poly = model_poly.predict(X)
print(f'Real X test Data: {y}')
print(f'First Prediction: {y_pred_poly}')

print('Mean Sq Error: %.2f'%mean_squared_error(y,y_pred_poly))
print('Coefficients determination: %.2f'%r2_score(y,y_pred_poly))

#y_pred_poly_2021 = model_poly.predict(poly.transform([[2021]]))
#print(f'production Prediction 2021: {y_pred_poly_2021}')

#data['Prediction_poly'] = model_poly.predict(poly.transform(X))
# Out:
# Real X test Data: [ 4  5  7 10 15]
# First Prediction: [ 3.34146341  4.8597561   7.89634146 10.93292683 13.9695122 ]
# Mean Sq Error: 0.64
# Coefficients determination: 0.96

# %%
plt.plot(X,y,'b.')
plt.plot(X,y_pred_poly)
plt.plot(X,y_pred_poly,'go')

# %%
X_sq = np.random.rand(100,1)
y_sq = X_sq ** 2 
plt.plot(X_sq,y_sq,'b.')

# %%
from sklearn.preprocessing import PolynomialFeatures

poly = PolynomialFeatures(degree=2)
Xpoly = poly.fit_transform(X_sq)
#X_test_poly = poly.transform(X_test)

model_poly = LinearRegression()
model_poly.fit(Xpoly,y_sq)

y_pred_poly = model_poly.predict(Xpoly)
#print(f'Real X test Data: {y_sq}')
#print(f'First Prediction: {y_pred_poly}')

print('Mean Sq Error: %.2f'%mean_squared_error(y_sq,y_pred_poly))
print('Coefficients determination: %.2f'%r2_score(y_sq,y_pred_poly))
# Out:
# Mean Sq Error: 0.00
# Coefficients determination: 1.00

# %%
plt.plot(X_sq,y_sq,'b.')
plt.plot(Xpoly,y_pred_poly,'r.',alpha=.4)

# %%
from sklearn.feature_selection import
